# %% [markdown]
# ### 1. 파일 불러오기 및 합치기

# %%
import pandas as pd

df1= pd.read_csv("c:/bankruptcy/data/ALL.부도어음집계_p.csv")
df1.head()
# Out:
#        ym local  bill  rsn  cnt    amt
# 0  201808     1     1    1    2  60000
# 1  201808     1     1    2    3  90000
# 2  201808     1     1    3    2  21000
# 3  201808     1     1    4    1  35000
# 4  201808     1     1    6    3  27000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7902 entries, 0 to 7901
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ym      7902 non-null   int64
#  1   local   7902 non-null   object
#  2   bill    7902 non-null   int64
#  3   rsn     7902 non-null   int64
#  4   cnt     7902 non-null   int64
#  5   amt     7902 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 370.5+ KB

# %%
df2 = pd.read_csv("c:/Bankruptcy/data/독립변수.csv")
df2.head()
# Out:
#        ym    kospi     usd     cny      jpy   call    cd   bond  unemp  \
# 0  201808  2322.88  1108.8  162.29   998.65  3.425  3.61  3.452    4.0
# 1  201809  2343.07  1112.7  161.78   981.17  3.425  3.52  3.528    3.6
# 2  201810  2029.69  1140.6  163.59  1008.89  3.269  3.80  3.584    3.5
# 3  201811  2096.86  1121.8  161.73   988.98  3.235  4.02  3.705    3.2
# 4  201812  2041.04  1118.1  162.76  1013.18  3.096  3.99  3.838    3.4
#
#      p_pi     c_pi  exp_pi  imp_pi  house_pi  bk_rate  coloan  peloan  chkloan
# 0  104.32   99.462  106.09  111.18    78.460     0.07    5.24    4.95     5.11
# 1  104.62  100.221  106.30  113.03    79.232     0.14    5.24    4.84     5.11
# 2  104.26  100.041  106.82  115.02    79.677     0.09    5.13    4.66     5.23
# 3  103.53   99.330  103.48  109.36    79.799     0.18    4.87    4.43     5.63
# 4  103.03   98.988  100.61  105.31    79.861     0.07    4.54    4.18     5.22

# %%
df=pd.merge(df1,df2, how="outer")
df.head()
# Out:
#        ym local  bill  rsn  cnt    amt    kospi     usd     cny     jpy  ...  \
# 0  201808     1     1    1    2  60000  2322.88  1108.8  162.29  998.65  ...
# 1  201808     1     1    2    3  90000  2322.88  1108.8  162.29  998.65  ...
# 2  201808     1     1    3    2  21000  2322.88  1108.8  162.29  998.65  ...
# 3  201808     1     1    4    1  35000  2322.88  1108.8  162.29  998.65  ...
# 4  201808     1     1    6    3  27000  2322.88  1108.8  162.29  998.65  ...
#
#    unemp    p_pi    c_pi  exp_pi  imp_pi  house_pi  bk_rate  coloan  peloan  \
# 0    4.0  104.32  99.462  106.09  111.18     78.46     0.07    5.24    4.95
# 1    4.0  104.32  99.462  106.09  111.18     78.46     0.07    5.24    4.95
# 2    4.0  104.32  99.462  106.09  111.18     78.46     0.07    5.24    4.95
# 3    4.0  104.32  99.462  106.09  111.18     78.46     0.07    5.24    4.95
# 4    4.0  104.32  99.462  106.09  111.18     78.46     0.07    5.24    4.95
#
#    chkloan
# 0     5.11
# 1     5.11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7902 entries, 0 to 7901
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ym        7902 non-null   int64
#  1   local     7902 non-null   object
#  2   bill      7902 non-null   int64
#  3   rsn       7902 non-null   int64
#  4   cnt       7902 non-null   int64
#  5   amt       7902 non-null   int64
#  6   kospi     7902 non-null   float64
#  7   usd       7902 non-null   float64
#  8   cny       7902 non-null   float64
#  9   jpy       7902 non-null   float64
#  10  call      7902 non-null   float64
#  11  cd        7902 non-null   float64
#  12  bond      7902 non-null   float64
#  13  unemp     7902 non-null   float64
#  14  p_pi      7902 non-null   float64
#  15  c_pi      7902 non-null   float64
#  16  exp_pi    7902 non-null   float64
#  17  imp_pi    7902 non-null   float64
#  18  house_pi  7902 non-null   float64
#  19  bk_rate   7902 non-null   float64
# ...

# %%
df.describe().transpose()
# Out:
#            count          mean           std         min         25%  \
# ym        7902.0  2.020056e+05  1.362867e+02  201808.000  201905.000
# bill      7902.0  4.292964e+00  2.351710e+00       1.000       2.000
# rsn       7902.0  3.034675e+00  1.887163e+00       1.000       2.000
# cnt       7902.0  1.153746e+01  3.275149e+01       1.000       1.000
# amt       7902.0  1.114965e+06  8.833894e+06    1000.000   11000.000
# kospi     7902.0  2.366108e+03  3.853721e+02    1754.640    2083.480
# usd       7902.0  1.182805e+03  6.976355e+01    1088.000    1130.000
# cny       7902.0  1.735864e+02  9.400356e+00     161.730     167.140
# jpy       7902.0  1.046442e+03  5.462931e+01     942.220    1007.620
# call      7902.0  1.492123e+00  9.254840e-01       0.480       0.560
# cd        7902.0  1.777485e+00  1.042557e+00       0.630       0.790
# bond      7902.0  1.795488e+00  1.034200e+00       0.611       0.910
# unemp     7902.0  3.620134e+00  6.887773e-01       2.100       3.100
# ...

# %%
df.to_csv("c:/bankruptcy/data/bankruptcy.csv")
